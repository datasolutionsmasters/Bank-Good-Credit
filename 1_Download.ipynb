# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import researchpy as rp
from scipy import stats

# Create Connection object and get list of tables
connString = 'mysql+pymysql://dm_team1:dm_team1123#@18.136.56.185:3306/project_banking'
conn = create_engine(connString)
stmt = "SELECT * FROM  INFORMATION_SCHEMA.TABLES"
df0 = pd.read_sql(stmt,conn)

df0.tail()
# Out:
#    TABLE_CATALOG        TABLE_SCHEMA                TABLE_NAME   TABLE_TYPE  \
# 57           def  information_schema  INNODB_BUFFER_POOL_STATS  SYSTEM VIEW
# 58           def  information_schema          INNODB_FT_CONFIG  SYSTEM VIEW
# 59           def     project_banking              Cust_Account   BASE TABLE
# 60           def     project_banking         Cust_Demographics   BASE TABLE
# 61           def     project_banking              Cust_Enquiry   BASE TABLE
#
#     ENGINE  VERSION ROW_FORMAT  TABLE_ROWS  AVG_ROW_LENGTH  DATA_LENGTH  \
# 57  MEMORY       10      Fixed         NaN             257            0
# 58  MEMORY       10      Fixed         NaN            1163            0
# 59  InnoDB       10    Compact    181335.0             217     39403520
# 60  InnoDB       10    Compact     23461.0             516     12107776
# 61  InnoDB       10    Compact    392967.0              76     29949952
#
# ...

# %%
# Download the 3 files
stmt = "SELECT * FROM  Cust_Account"
df1 = pd.read_sql(stmt,conn)


stmt = "SELECT * FROM  Cust_Enquiry"
df2 = pd.read_sql(stmt,conn)

 
stmt = "SELECT * FROM  Cust_Demographics"
df3 = pd.read_sql(stmt,conn)

# %%
print("Shape of Cust_Account      :",df1.shape)
print("Shape of Cust_Enquiry      :",df2.shape)
print("Shape of Cust_Demographics :",df3.shape)
# Out:
# Shape of Cust_Account      : (186329, 21)
# Shape of Cust_Enquiry      : (413188, 6)
# Shape of Cust_Demographics : (23896, 83)

# %%
# Save Files
df1.to_csv('1_Cust_Account.csv',index=False)
df2.to_csv('1_Cust_Enquiry.csv',index=False)
df3.to_csv("1_Cust_Demographics.csv",index=False)
